# %% [markdown]
# **Install the necessary libraries**

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
from ultralytics import YOLO
ultralytics.checks()

import os
from google.colab import drive
import cv2
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.9/78.2 GB disk)

# %% [markdown]
# **Mount your Google Drive (Permit and trust)**

# %%
MOUNTPOINT = '/content/gdrive'
DATADIR = os.path.join(MOUNTPOINT, 'My Drive', 'Colab Notebooks')
drive.mount(MOUNTPOINT)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Check acces and the content of your google drive**

# %%
print("Files and folders: ", os.listdir(DATADIR))
print("Full path: ", DATADIR)
# Out:
# Files and folders:  ['datasets', '2_Yolov8_Predict.ipynb', 'test_img.jpg', 'test_img_predict.jpg', 'Kopie von 0_yolov8_FirstSteps.ipynb', '0_yolov8_FirstSteps.ipynb', '1_Yolov8_Train.ipynb']
# Full path:  /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# **Start a custom training (transfer learning)**

# %%
 # Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model
model.train(data="/content/gdrive/My Drive/Colab Notebooks/datasets/boars/boars_colab.yaml", epochs=100, imgsz=640, project="/content/gdrive/My Drive/Colab Notebooks/datasets/boars/training_runs")  # train the model (transfer learning)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 80.6MB/s]
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
