# %% [markdown]
# **Install the necessary libraries**

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
from ultralytics import YOLO
ultralytics.checks()

import os
from google.colab import drive
import cv2
# Out:
# Ultralytics YOLOv8.0.97 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %% [markdown]
# **Mount your Google Drive (Permit and trust)**

# %%
MOUNTPOINT = '/content/gdrive'
DATADIR = os.path.join(MOUNTPOINT, 'My Drive', 'Colab Notebooks')
drive.mount(MOUNTPOINT)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Check acces and the content of your google drive**

# %%
print("Files and folders: ", os.listdir(DATADIR))
print("Full path: ", DATADIR)
# Out:
# Files and folders:  ['datasets', 'test_img.jpg', 'predict.jpg', '1_Yolov8_Train.ipynb', 'predict_henne.jpg', '2_Yolov8_Results.ipynb', '0_yolov8_FirstSteps.ipynb']
# Full path:  /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# **Test a already existing model on an image**

# %%
# Load a model
model = YOLO("yolov8l.pt")  # load a pretrained model n: nano s: small m:medium l: large

# Use the model
results = model("/content/gdrive/My Drive/Colab Notebooks/test_img.jpg")  # predict on an image

# Save the results
res_plotted = results[0].plot()
cv2.imwrite('/content/gdrive/My Drive/Colab Notebooks/predict.jpg', res_plotted)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8l.pt to yolov8l.pt...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 132MB/s]
#
# image 1/1 /content/gdrive/My Drive/Colab Notebooks/test_img.jpg: 640x480 12 persons, 1 laptop, 78.0ms
# Speed: 14.6ms preprocess, 78.0ms inference, 36.6ms postprocess per image at shape (1, 3, 640, 640)
# True

# %%
os.listdir("/content") # file storage on google colab
# Out:
# ['.config', 'yolov8l.pt', 'gdrive']
