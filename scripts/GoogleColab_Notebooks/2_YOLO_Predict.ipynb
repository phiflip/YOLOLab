# %% [markdown]
# **Install the necessary libraries**

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
from ultralytics import YOLO
ultralytics.checks()

import os
from google.colab import drive
import cv2
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.9/78.2 GB disk)

# %% [markdown]
# **Mount your Google Drive (Permit and trust)**

# %%
MOUNTPOINT = '/content/gdrive'
DATADIR = os.path.join(MOUNTPOINT, 'My Drive', 'Colab Notebooks')
drive.mount(MOUNTPOINT)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Check acces and the content of your google drive**

# %%
print("Files and folders: ", os.listdir(DATADIR))
print("Full path: ", DATADIR)
# Out:
# Files and folders:  ['datasets', 'test_img.jpg', 'test_img_predict.jpg', '0_yolov8_FirstSteps.ipynb', '1_Yolov8_Train.ipynb', '2_Yolov8_Predict.ipynb']
# Full path:  /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# **Load the model from custom training (transfer learning)**

# %%
# Load a model
model = YOLO("/content/gdrive/My Drive/Colab Notebooks/datasets/boars/training_runs/train/weights/best.pt")

# Use the model to make predictions
results = model("/content/gdrive/My Drive/Colab Notebooks/datasets/boars/test/",
                save=True,
                project="/content/gdrive/My Drive/Colab Notebooks/datasets/boars/predictions/",
                name="yolov8n_imgsz640",
                )
# Out:
# image 1/3 /content/gdrive/My Drive/Colab Notebooks/datasets/boars/test/171749_480.jpg: 384x640 10 boars, 7.2ms
# image 2/3 /content/gdrive/My Drive/Colab Notebooks/datasets/boars/test/172447_768.jpg: 384x640 9 boars, 7.2ms
# image 3/3 /content/gdrive/My Drive/Colab Notebooks/datasets/boars/test/172832_4992.jpg: 384x640 12 boars, 7.2ms
# Speed: 2.4ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/gdrive/My Drive/Colab Notebooks/datasets/boars/predictions/yolov8n_imgsz640
