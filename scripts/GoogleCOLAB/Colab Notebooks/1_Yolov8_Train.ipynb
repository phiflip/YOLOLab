# %% [markdown]
# **Install the necessary libraries**

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
from ultralytics import YOLO
ultralytics.checks()

import os
from google.colab import drive
import cv2
# Out:
# Ultralytics YOLOv8.0.51 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.4/78.2 GB disk)

# %% [markdown]
# **Mount your Google Drive (Permit and trust)**

# %%
MOUNTPOINT = '/content/gdrive'
DATADIR = os.path.join(MOUNTPOINT, 'My Drive', 'Colab Notebooks')
drive.mount(MOUNTPOINT)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Check acces and the content of your google drive**

# %%
print("Files and folders: ", os.listdir(DATADIR))
print("Full path: ", DATADIR)
# Out:
# Files and folders:  ['Untitled0.ipynb', 'testColab.ipynb', '2_Yolov8_Results.ipynb', 'datasets', 'test_img.jpg', 'predict.jpg', '0_yolov8_FirstSteps.ipynb', '1_Yolov8_Train.ipynb']
# Full path:  /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# **Start a custom training (transfer learning)**

# %%
 # Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model
model.train(data="/content/gdrive/My Drive/Colab Notebooks/datasets/hennen/hennen_Colab.yaml", epochs=100, imgsz=608, project="/content/gdrive/My Drive/Colab Notebooks/datasets/hennen/runs")  # train the model (transfer learning)
