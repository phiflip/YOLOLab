# %% [markdown]
# **Install the necessary libraries**

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
from ultralytics import YOLO
ultralytics.checks()

import os
from google.colab import drive
import cv2
# Out:
# Ultralytics YOLOv8.0.51 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.4/78.2 GB disk)

# %% [markdown]
# **Mount your Google Drive (Permit and trust)**

# %%
MOUNTPOINT = '/content/gdrive'
DATADIR = os.path.join(MOUNTPOINT, 'My Drive', 'Colab Notebooks')
drive.mount(MOUNTPOINT)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Check acces and the content of your google drive**

# %%
print("Files and folders: ", os.listdir(DATADIR))
print("Full path: ", DATADIR)
# Out:
# Files and folders:  ['datasets', 'test_img.jpg', 'predict.jpg', '0_yolov8_FirstSteps.ipynb', '1_Yolov8_Train.ipynb', '2_Yolov8_Results.ipynb']
# Full path:  /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# **Load the model from custom training (transfer learning)**

# %%
# Load a model
model = YOLO("/content/gdrive/My Drive/Colab Notebooks/datasets/hennen/runs/train/weights/best.pt")  

# Use the model
results = model("/content/gdrive/My Drive/Colab Notebooks/datasets/hennen/test/images/AviForum_Hennen_608x608 014.jpg")  # predict on an image

# Save the results
res_plotted = results[0].plot()
cv2.imwrite("/content/gdrive/My Drive/Colab Notebooks/predict_henne.jpg", res_plotted)
# Out:
# image 1/1 /content/gdrive/My Drive/Colab Notebooks/datasets/hennen/test/images/AviForum_Hennen_608x608 014.jpg: 608x608 34 hennes, 2 henneGPSs, 11.3ms
# Speed: 0.7ms preprocess, 11.3ms inference, 41.8ms postprocess per image at shape (1, 3, 608, 608)
# True
